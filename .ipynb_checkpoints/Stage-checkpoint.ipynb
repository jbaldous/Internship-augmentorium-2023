# %%
# %reset -f
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from matplotlib import cm

# %% [markdown]
# # Simulation d'un augmentorium :

# %% [markdown]
# ## 1) **Première approche : Uniquement l'insecte ravageur sans adimensionalisation**

# %% [markdown]
# On va considérer le système suivant :
# $$
# \left\{\begin{array}{1}
# \dot x = r_xx(1-\frac{x}{K_x})-mx+fy\\
# \dot y = r_yy(1-\frac{y}{K_y})+mx-fy
# \end{array}\right.
# $$
#
# avec $ \dot x $ la population de ravageurs dans la culture et $ \dot y $ celle dans l'augmentorium.
# $ m $ est alors le taux de fruit mis dans l'augmentorium et $ f $ le taux de fuite des ravageurs, de l'augmentorium vers la culture.

# %% [markdown]
# ### Dynamique :

# %%
# Définition du modèle :
def aug(etat,t,param):
    rx,ry,Kx,Ky,m,f=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-m*x+f*y,ry*y*(1-y/Ky)+m*x-f*y]
    return s 

# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres 1 : On a rx1=0.5 pour mimer la libération de parasite,ry1 est le taux de reproduction dans l'augmentorium faible due à l'effet des parasites
# sur la reproduction des ravageurs. La capacité biotique de la culture est logiquement plus forte que celle de l'augmentorium. Les taux de migrations sont ceux d'un augmentorium.

rx1=0.5
ry1=1
Kx1=2
Ky1=1
m1=2
f1=0.2

param_aug1=np.array([rx1,ry1,Kx1,Ky1,m1,f1])

#Paramètres 2 2.5 dans la culture pour mimer la non libération de parasites ou alors leur faible efficacité (dues aux pesticides). La non libération causerait un ry2 = 2.5.

rx2=2.5
ry2=1 #idée : par exemple 1 si des pesticides (et donc les parasites sont efficaces seulement dans l'augmentorium et 2.5 si non libération).
Kx2=2
Ky2=1
m2=2
f2=0.2

param_aug2=np.array([rx2,ry2,Kx2,Ky2,m2,f2])

# Simulation avec r variable
s1=odeint(aug,e0,ti,args=(param_aug1,))
s2=odeint(aug,e0,ti,args=(param_aug2,))

## Dessin de la dynamique de a population avec param 1:
fig,(ax,ax1)=plt.subplots(2,1,figsize=(9,9))
fig.suptitle('Dynamique des ravageurs dans le temps avec augmentorium')
ax.set_title('Config 1')
ax.plot(ti,s1[:,0],color='C1',label='culture')
ax.plot(ti,s1[:,1],color='C0',label='augmentorium')
ax.grid()
ax.legend()
ax.set_xlabel('Temps,t')
ax.set_ylabel('Densité de pop.')

# Dessin de la dynamique de a population avec param 2:
ax1.plot(ti,s2[:,0],color='C1',label='culture')
ax1.plot(ti,s2[:,1],color='C0',label='augmentorium')
ax1.grid()
ax1.legend()
ax1.set_xlabel('Temps,t')
ax1.set_ylabel('Densité de pop.')
ax1.set_title('Config 2')
# Out:
# Text(0.5, 1.0, 'Config 2')

# %% [markdown]
# La baisse des ravageurs dans la culture est significative.

# %% [markdown]
# ### Plan de phase :

# %%
fig2,(ax2,ax3)=plt.subplots(2,1,figsize=(15,15))
fig2.suptitle('Plan de phase de la population')
ax2.set_title('Config 1')
ax3.set_title('Config 2')

#Plan de phase 1:

# Isocline nulles
#xdot = 0 --> y=x*1/f*(r(x/Kx-1)+m)
xt=np.arange(0,10,0.01)
ax2.plot(xt,xt*(1/f1)*(rx1*((xt/Kx1)-1)+m1),color='C2',label='xdot=0')
#ydot = 0 --> x=y*1/m*(r(y/Ky-1)+f)
yt=np.arange(0,10,0.01)
ax2.plot(yt*(1/m1)*(ry1*((yt/Ky1)-1)+f1),yt,color='C3',label='ydot=0')

ax2.set_xlim(left=0,right=3)
ax2.set_ylim(top=3,bottom=0)
ax2.plot(s1[:,0],s1[:,1],label='Trajectoire de la pop.')
ax2.set_xlabel('Ravageur dans la culture',fontsize='12')
ax2.set_ylabel('Ravageur dans l\'augmentorium',fontsize='12')

# Ajout du champ de vecteur
xg=np.arange(-0.5,3,0.3)
yg=np.arange(-0.5,3,0.3)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug1)
ax2.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=150,width=0.002)


#Plan de phase avec les paramètres 2 

# Isocline nulles
#xdot = 0 --> y=x*1/f*(r(x/Kx-1)+m)
xt=np.arange(0,10,0.01)
ax3.plot(xt,xt*(1/f2)*(rx2*((xt/Kx2)-1)+m2),color='C2',label='xdot=0')
#ydot = 0 --> x=y*1/m*(r(y/Ky-1)+f)
yt=np.arange(0,10,0.01)
ax3.plot(yt*(1/m2)*(ry2*((yt/Ky2)-1)+f2),yt,color='C3',label='ydot=0')

ax3.set_xlim(left=0,right=3)
ax3.set_ylim(top=3,bottom=0)
ax3.plot(s2[:,0],s2[:,1],label='Trajectoire de la pop.')
ax3.set_xlabel('Ravageur dans la culture',fontsize='12')
ax3.set_ylabel('Ravageur dans l\'augmentorium',fontsize='12')

# Ajout du champ de vecteur
xg=np.arange(-0.5,3,0.3)
yg=np.arange(-0.5,3,0.3)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug2)
ax3.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=150,width=0.002)


x=np.arange(0,10,0.01)
ax3.plot(x,-x+Kx1+Ky1,label='Kx1+Ky1')
ax2.plot(x,-x+Kx1+Ky1,label='Kx1+Ky1')
ax3.legend()
ax2.legend()

# %% [markdown]
# On observe deux équilibres, **(0,0)** qui est instable et (x*,y*) qui est **stable** (par le champ de vecteurs). Ceci montre que la population tend à se stabiliser entre l'augmentorium et l'extérieur. Dans ce modèle on a jamais disparition du ravageur. En fonction de son taux de reproduction dans la culture on a pas forcément le même équilibre, la trajectoire pour y arriver n'est pas non plus la même.
#
# Si le **taux de migration n'est pas le même**, ie qu'on séquestre les ravageurs dans l'augmentorium alors, si le taux de croissance dans les cultures est faible, il y a un **équilibre avec peu de ravageurs en culture** (deux fois moins que pour un taux de reproduction fort) atteint pour un faible taux de ravageur dans l'augmentorium. C'est ce qui peut se passer si on inclut la **présence de parasites** qui viennent augmenter la mortalité des ravageurs dans la culture et qui se reproduisent.
#
# Ainsi les mesures prophylactiques de séquestration des fruits infestés sont dans tous les cas **efficaces** pour réduire l'infestation. Couplées à la libération de parasites (ou en tout cas à une baisse du taux de croissance dans les cultures) elles peuvent encore être améliorée.

# %% [markdown]
# ## 2) **Effet réel de l'augmentorium**

# %% [markdown]
# ### Dynamique :

# %%
# Définition du modèle :
def aug(etat,t,param):
    rx,ry,Kx,Ky,m,f=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-m*x+f*y,ry*y*(1-y/Ky)+m*x-f*y]
    return s 

# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres simulant un simple débarassage des fruits, reproduction entre la tente et l'extérieur similaire, taux de migration égal entre les deux structures
rx1=1
ry1=1
Kx1=2
Ky1=1
m1=1
f1=1

param_aug1=np.array([rx1,ry1,Kx1,Ky1,m1,f1])

#Paramètres simulant la présence d'un augmentorium --> baisse du taux de reproduction dans le verger et taux de fuite très inférieur au taux de migration.
rx2=0.5
ry2=1
Kx2=2
Ky2=1
m2=2
f2=0.2

param_aug2=np.array([rx2,ry2,Kx2,Ky2,m2,f2])

# Simulation avec r variable
s1=odeint(aug,e0,ti,args=(param_aug1,))
s2=odeint(aug,e0,ti,args=(param_aug2,))

## Dessin de la dynamique de a population avec param 1:
fig,(ax,ax1)=plt.subplots(2,1,figsize=(9,9))
fig.suptitle('Dynamique des ravageurs dans le temps avec augmentorium')
ax.set_title('Config 1')
ax.plot(ti,s1[:,0],color='C1',label='culture')
ax.plot(ti,s1[:,1],color='C0',label='augmentorium')
ax.grid()
ax.legend()
ax.set_xlabel('Temps,t')
ax.set_ylabel('Densité de pop.')

# Dessin de la dynamique de a population avec param 2:
ax1.plot(ti,s2[:,0],color='C1',label='culture')
ax1.plot(ti,s2[:,1],color='C0',label='augmentorium')
ax1.grid()
ax1.legend()
ax1.set_xlabel('Temps,t')
ax1.set_ylabel('Densité de pop.')
ax1.set_title('Config 2')
# Out:
# Text(0.5, 1.0, 'Config 2')

# %% [markdown]
# La baisse des ravageurs dans la culture est significative.

# %% [markdown]
# ### Plan de phase :

# %%
fig2,(ax2,ax3)=plt.subplots(2,1,figsize=(15,15))
fig2.suptitle('Plan de phase de la population')
ax2.set_title('Config 1')
ax3.set_title('Config 2')

#Plan de phase 1:

# Isocline nulles
#xdot = 0 --> y=x*1/f*(r(x/Kx-1)+m)
xt=np.arange(0,10,0.01)
ax2.plot(xt,xt*(1/f1)*(rx1*((xt/Kx1)-1)+m1),color='C2',label='xdot=0')
#ydot = 0 --> x=y*1/m*(r(y/Ky-1)+f)
yt=np.arange(0,10,0.01)
ax2.plot(yt*(1/m1)*(ry1*((yt/Ky1)-1)+f1),yt,color='C3',label='ydot=0')

ax2.set_xlim(left=0,right=3)
ax2.set_ylim(top=3,bottom=0)
ax2.plot(s1[:,0],s1[:,1],label='Trajectoire de la pop.')
ax2.set_xlabel('Ravageur dans la culture',fontsize='12')
ax2.set_ylabel('Ravageur dans l\'augmentorium',fontsize='12')

# Ajout du champ de vecteur
xg=np.arange(-0.5,3,0.3)
yg=np.arange(-0.5,3,0.3)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug1)
ax2.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=200,width=0.004)


#Plan de phase avec les paramètres 2 

# Isocline nulles
#xdot = 0 --> y=x*1/f*(r(x/Kx-1)+m)
xt=np.arange(0,10,0.01)
ax3.plot(xt,xt*(1/f2)*(rx2*((xt/Kx2)-1)+m2),color='C2',label='xdot=0')
#ydot = 0 --> x=y*1/m*(r(y/Ky-1)+f)
yt=np.arange(0,10,0.01)
ax3.plot(yt*(1/m2)*(ry2*((yt/Ky2)-1)+f2),yt,color='C3',label='ydot=0')

ax3.set_xlim(left=0,right=3)
ax3.set_ylim(top=3,bottom=0)
ax3.plot(s2[:,0],s2[:,1],label='Trajectoire de la pop.')
ax3.set_xlabel('Ravageur dans la culture',fontsize='12')
ax3.set_ylabel('Ravageur dans l\'augmentorium',fontsize='12')

# Ajout du champ de vecteur
xg=np.arange(-0.5,3,0.3)
yg=np.arange(-0.5,3,0.3)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug2)
ax3.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=200,width=0.004)


x=np.arange(0,10,0.01)
ax3.plot(x,-x+Kx1+Ky1,label='Kx1+Ky1')
ax2.plot(x,-x+Kx1+Ky1,label='Kx1+Ky1')
ax3.legend()
ax2.legend()

# %% [markdown]
# On observe que l'augmentorium a un réel effet. Le débarassage des fruits de la culture permet une légère diminution de la population dans celle-ci. Mais la méthode de **séquestration**/libération de parasite due à l'augmentorium est bien plus efficace. Les équilibres sont largement déplacés vers une forte baisse des ravageurs en culture. Ceci est principalement du à la séquestration. Une étude plus poussée sur l'effet des parasites augmentés est recommandée.

# %% [markdown]
# ## 3) **Etude d'une population répartie en deux structures spatiales :**

# %% [markdown]
# ### Equilibres

# %% [markdown]
# On part d'un modèle tel que :
# $$
# \left\{\begin{array}{1}
# \dot x = r_xx\left(1-\frac{x}{K_x}\right)-\beta(x-y)\\
# \dot y = r_yy\left(1-\frac{y}{K_y}\right)+\beta(x-y)
# \end{array}\right.
# $$
#
# avec $ \dot x $ la population de ravageurs dans la culture et $ \dot y $ celle dans l'augmentorium.
# $ \beta $ le taux de migration entre la structure et la culture.

# %%
#Définition du modèle et des paramètres :
def aug(etat,t,param):
    rx,ry,Kx,Ky,b=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-b*(x-y),ry*y*(1-y/Ky)+b*(x-y)]
    return s 

# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres:
rx=0.5
ry=1
Kx=2
Ky=1
b=0.8

param_aug=np.array([rx,ry,Kx,Ky,b])

# Simulation:
s=odeint(aug,e0,ti,args=(param_aug,))

#Plan de phase:
fig,ax=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax.plot(xt,xt*(1/b)*(rx*((xt/Kx)-1)+b),color='C2',label='xdot=0')
ax.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax.plot(yt*(1/b)*(ry*((yt/Ky)-1)+b),yt,color='C3',label='ydot=0')
ax.plot(xt,np.zeros_like(xt),color='C2')



ax.set_xlim(left=-1,right=3)
ax.set_ylim(top=3,bottom=-1)
#ax2.plot(s[:,0],s[:,1],label='Trajectoire de la pop.')
ax.set_xlabel('x',fontsize='12')
ax.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C7')

# Ajout du champ de vecteur
#xg=np.arange(-0.5,3,0.3)
#yg=np.arange(-0.5,3,0.3)
#X,Y=np.meshgrid(xg,yg)

#dx,dy=aug([X,Y],0,param_aug)
#ax.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=200,width=0.004)

# %% [markdown]
# Maintenant on remarque que il y a deux équilibres (intersection de nullclines). En (0,0) et en (x*,y*). On va calculer (x*,y*):

# %% [markdown]
# $$
# \left\{\begin{array}{1}
# \dot x = 0 \Leftrightarrow x=0 \vee y^*=r_xx^*\left(\frac{1}{r_x}-\frac{1}{\beta}+\frac{x^*}{\beta K_x}\right)\\
# \dot y =0 \Leftrightarrow y=0 \vee x^*=r_yy^*\left(\frac{1}{r_y}-\frac{1}{\beta}+\frac{y^*}{\beta K_y}\right)
# \end{array}\right.
# $$

# %% [markdown]
# L'équilibre $ (0,0) $ apparaît alors trivialement. Pour calculer $(x^*,y^*)$ on va injecter $x^*$ dans $y^*$. Ceci donne après développement et factorisation un polynôme du quatrième degré :

# %% [markdown]
# $$
# y\left(r_xr_y\left[\frac{1}{\beta}\left(\frac{1}{\beta}-\frac{1}{r_x}-\frac{1}{r_y}\right)+\frac{1}{r_xr_y}\right]-1\right)+
# \frac{y^2r_xr_y}{\beta}\left[\frac{1}{K_y}\left(\frac{1}{r_x}-\frac{1}{\beta}\right)+\frac{1}{K_x}\left(\frac{1}{r_y}-\frac{2}{\beta}+\frac{r_y}{\beta^2}\right)\right]+\\
# \frac{2y^3r_xr_y}{\beta^2 K_xK_y}\left(1-\frac{r_y}{\beta}\right)+
# \frac{y^4r_xr_y^2}{\beta^3K_y^2K_x} = 0
# $$

# %% [markdown]
# Qu'on va résoudre grâce à numpy :

# %%
# Paramètres:
rx=0.5
ry=1
Kx=2
Ky=1
b=0.8

param_aug=np.array([rx,ry,Kx,Ky,b])
###
#Monome y
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol = y*(rx*ry*((1/b)*((1/b)-(1/rx)-(1/ry))+1/(rx*ry))-1)+(y**2)*((rx*ry)/b)*((1/Ky)*((1/rx)-(1/b))+(1/Kx)*((1/ry)-(2/b)+(ry/(b**2))))+2*(y**3)*((rx*ry)/((b**2)*Kx*Ky))*(1-(ry/b))+(y**4)*((rx*(ry**2))/((b**3)*(Ky**2)*Kx))
#pol2 = y*(1-ry/b-rx/b+(rx*ry)/(b**2)) + (y**2)*(ry/(b*Ky)+rx/(b*Kx)-(rx*ry)/((b**2)*Ky)-(2*rx*ry)/((b**2)*Kx)+(rx*(ry**2))/((b**3)*Kx))+(y**3)*((2*rx*ry)/((b**2)*Kx*Ky)-(2*rx*(ry**2))/((b**3)*Kx*Ky))+(y**4)*(rx*(ry**2))/((b**3)*Kx*(Ky**2))
#Solution
sol = pol.roots()[(np.isreal(pol.roots())) 
            *(pol.roots() > 0)]
yeq=sol[0].real
xeq=(ry*yeq*((1/ry)-(1/b)+(yeq/(b*Ky)))).real
###

#Affichage du nouveau graphe avec le point d'intersection:
#Plan de phase:
fig,ax=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax.plot(xt,xt*(1/b)*(rx*((xt/Kx)-1)+b),color='C2',label='xdot=0')
ax.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax.plot(yt*(1/b)*(ry*((yt/Ky)-1)+b),yt,color='C3',label='ydot=0')
ax.plot(xt,np.zeros_like(xt),color='C2')

ax.set_xlim(left=-1,right=3)
ax.set_ylim(top=3,bottom=-1)
ax.set_xlabel('x',fontsize='12')
ax.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C7')

ax.plot(xeq.real,yeq.real,label='Equilibre stable',marker='.',markersize=10)
ax.plot(0,0,label='Equilibre Instable',marker='.',markersize=10)

ax.legend()

# Ajout du champ de vecteur
xg=np.arange(0,5,0.6)
yg=np.arange(0,5,0.6)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug)
ax.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=80,width=0.003)

# %% [markdown]
# De plus, en faisant $ x^* + y^* $ on a (en abandonnant les étoiles par commodité):
# $$
# r_xx\left(1-\frac{x}{K_x}\right)+r_yy\left(1-\frac{y}{K_y}\right) = 0 \\
# $$
# autrement dit l'équation d'une ellipse. Donc les points d'équilibres vivent sur une ellipse (si on ne modifie que beta), qu'on va tracer :

# %%
# Paramètres:
rx=1
ry=1
Kx=2
Ky=1
b=0.5

param_aug=np.array([rx,ry,Kx,Ky,b])
#####################
#Monome y
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol = y*(rx*ry*((1/b)*((1/b)-(1/rx)-(1/ry))+1/(rx*ry))-1)+(y**2)*((rx*ry)/b)*((1/Ky)*((1/rx)-(1/b))+(1/Kx)*((1/ry)-(2/b)+(ry/(b**2))))+2*(y**3)*((rx*ry)/((b**2)*Kx*Ky))*(1-(ry/b))+(y**4)*((rx*(ry**2))/((b**3)*(Ky**2)*Kx))
#Solution
sol = pol.roots()[(np.isreal(pol.roots())) 
            *(pol.roots() > 0)]
yeq=sol[0].real
xeq=(ry*yeq*((1/ry)-(1/b)+(yeq/(b*Ky)))).real


#Affichage du nouveau graphe avec le point d'intersection:
#Plan de phase:
fig,ax=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax.plot(xt,xt*(1/b)*(rx*((xt/Kx)-1)+b),color='C2',label='xdot=0')
ax.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax.plot(yt*(1/b)*(ry*((yt/Ky)-1)+b),yt,color='C3',label='ydot=0')
ax.plot(xt,np.zeros_like(xt),color='C2')



ax.set_xlim(left=-1.5,right=3)
ax.set_ylim(top=3,bottom=-1.5)
ax.set_xlabel('x',fontsize='12')
ax.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C9')

ax.plot(xeq.real,yeq.real,label='Equilibre stable',marker='.',markersize=12)
ax.plot(0,0,label='Equilibre Instable',marker='.',markersize=12,color='C5')

ax.legend()

# Ajout du champ de vecteur
xg=np.arange(0,5,0.6)
yg=np.arange(0,5,0.6)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug)
ax.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=80,width=0.003)
##################

#Trace de l'ellipse:
xg2=np.arange(-5,5,0.01)
yg2=np.arange(-5,5,0.01)
X2,Y2=np.meshgrid(xg2,yg2)
X=rx*X2*(1-X2/Kx)
Y=ry*Y2*(1-Y2/Ky)
ax.contour(X2,Y2,(X+Y),[0],colors='C1')
ax.plot(0,0,color='C1',label='Ellipse des solutions')
ax.legend(loc='lower left',fontsize = 8)

# %% [markdown]
# Si l'équilbre est au dessus de la droite cian alors on dit que le système subit une inflation c'est à dire que la valeur de l'équilibre final vaut plus que les deux capacités biotiques réunies ($ 1+1 \ne 2$). Petite animation Geogebra pour bien voir en fonction de beta que l'équilibre vit sur l'ellipse.

# %%
import IPython.display as display
fig01 = """
<iframe width="800" height="600" src="https://www.geogebra.org/classic/msgycwj7" style="border: 1px solid black"></iframe>
"""
display.HTML(fig01)
# Out:
# <iframe width="800" height="600" src="https://www.geogebra.org/classic/msgycwj7" style="border: 1px solid black"></iframe>

# %% [markdown]
# **Stabilité des équilibres:**
# Il est clair que $(0,0)$ est instable et $(x^*,y^*)$ est stable (par le champ de vecteur). Mathématiquement :
# $$
# \mathbb{J}=\left[\begin{array}{cc}
# \ r_x-\frac{2r_xx}{K_x}-\beta & \beta \\
# \ \beta & r_y -\frac{2r_yy}{K_y}-\beta
# \end{array}\right]
# $$
#  - et donc pour $(0,0)$:,
# $$
# \mathbb{J_{\vec{0}}}=\left[\begin{array} \\
# \ r_x-\beta & \beta \\
# \ \beta & r_y -\beta
# \end{array}\right]
# \\
# \Leftrightarrow
# \sigma_\mathbb{J} = (\lambda_1 = \frac{r_x+r_y-2\beta-2\beta\sqrt{\frac{(r_x-r_y)^2}{4\beta^2}+1}}{2},\lambda_2=\frac{r_x+r_y-2\beta+2\beta\sqrt{\frac{(r_x-r_y)^2}{4\beta^2}+1}}{2})
# $$
#   et on a ainsi,
# $$
# \lambda_2 > 0
# $$
#
#   Donc $(0,0)$ est bien instable, $\forall (x_0,y_0) \in \mathbb{R^2_+}$.
# - et pour $(x^*,y^*)$ après simplification (et en abandonnant les * par comodité) :
# $$ \mathbb{J_{x^*,y^*}} = \left[\begin{array} \\
# \ -\frac{\beta y}{x}-\frac{r_xx}{K_x} & \beta \\
# \ \beta & -\frac{\beta x}{y}-\frac{r_yy}{K_y}
# \end{array}\right]
# \\
# $$
# Il est alors facile de vérifier que la trace de cette matrice est négative pour tout $(x_0,y_0)$ et que le déterminant est positif pour tout $(x_0,y_0)$.
# Ainsi, $(x^*,y^*)$ est bien stable, $\forall (x_0,y_0) \in \mathbb{R^2_+}$.

# %% [markdown]
# ### Tangente et condition suffisante à un système déflationiste:

# %% [markdown]
# On remarque que le point$ (K_x,K_y)$ est en permanence sur la droite $K_x+K_y$ qui coupe en permanence l'ellipse sauf pour une situation où la droite $K_x+K_y$ est tangente à l'ellipse. Ce cas nous interesse car il rend compte d'un système entièrement déflationiste.
# L'ellipse d'équation : $f(x,y)=r_xx\left(1-\frac{x}{K_x}\right)+r_yy\left(1-\frac{y}{K_y}\right) = 0 $ peut être vue comme la ligne de niveau de $f$ en $0$. Ainsi une équation de la tangente au point $(x_0,y_0)$ serait donnée par:
# $  \frac{\partial f}{\partial x}(x_0,y_0)(x-x_0)+ \frac{\partial f}{\partial y}(x_0,y_0)(y-y_0) = 0$
#
# Dans le cas où $x_0=Kx y_0=Ky$ on a alors $y=-\frac{r_x}{r_y}\left(x-K_x\right) + K_y$ équation de la tangente au point $(K_x,K_y)$.
#
# Pour que le système soit déflationiste on veut que cette équation ait une pente de $-1$ afin d'avoir l'équation de la droite $K_x+K_y$ et garantir la déflation. Ainsi on veut que $r_x=r_y$.
#
# On sait donc que si le taux de croissance est égale entre les deux structures le système est tout le temps déflationiste.

# %%
# Paramètres:
rx=1
ry=1
Kx=2
Ky=1
b=0.5

param_aug=np.array([rx,ry,Kx,Ky,b])
#####################
#Monome y
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol = y*(rx*ry*((1/b)*((1/b)-(1/rx)-(1/ry))+1/(rx*ry))-1)+(y**2)*((rx*ry)/b)*((1/Ky)*((1/rx)-(1/b))+(1/Kx)*((1/ry)-(2/b)+(ry/(b**2))))+2*(y**3)*((rx*ry)/((b**2)*Kx*Ky))*(1-(ry/b))+(y**4)*((rx*(ry**2))/((b**3)*(Ky**2)*Kx))
#Solution
sol = pol.roots()[(np.isreal(pol.roots())) 
            *(pol.roots() > 0)]
yeq=sol[0].real
xeq=(ry*yeq*((1/ry)-(1/b)+(yeq/(b*Ky)))).real


#Affichage du nouveau graphe avec le point d'intersection:
#Plan de phase:
fig,ax=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax.plot(xt,xt*(1/b)*(rx*((xt/Kx)-1)+b),color='C2',label='xdot=0')
ax.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax.plot(yt*(1/b)*(ry*((yt/Ky)-1)+b),yt,color='C3',label='ydot=0')
ax.plot(xt,np.zeros_like(xt),color='C2')



ax.set_xlim(left=-1.5,right=3)
ax.set_ylim(top=3,bottom=-1.5)
ax.set_xlabel('x',fontsize='12')
ax.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C9')

ax.plot(xeq.real,yeq.real,label='Equilibre stable',marker='.',markersize=12)
ax.plot(0,0,label='Equilibre Instable',marker='.',markersize=12,color='C5')

ax.legend()

# Ajout du champ de vecteur
xg=np.arange(0,5,0.6)
yg=np.arange(0,5,0.6)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug)
ax.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=80,width=0.003)
##################

#Trace de l'ellipse:
xg2=np.arange(-5,5,0.01)
yg2=np.arange(-5,5,0.01)
X2,Y2=np.meshgrid(xg2,yg2)
X=rx*X2*(1-X2/Kx)
Y=ry*Y2*(1-Y2/Ky)
ax.contour(X2,Y2,(X+Y),[0],colors='C1')
ax.plot(0,0,color='C1',label='Ellipse des solutions')

xv=np.arange(0,10)
ax.plot(xv,-rx/ry*(xv-Kx)+Ky,color='C4',label='Tangente à (Kx,Ky)')
ax.plot(0,Ky,marker='.',markersize=7,color='k')
ax.plot(Kx,0,marker='.',markersize=7,color='k')
ax.plot(Kx,Ky,marker='.',markersize=6,color='k')
xc=np.arange(0,Kx,0.01)
ax.plot(xc,Ky*np.ones_like(xc),linestyle='dashed',color='k',linewidth=0.5)
yc=np.arange(0,Ky,0.01)
ax.plot(Kx*np.ones_like(yc),yc,linestyle='dashed',color='k',linewidth=0.5)
ax.text(-0.2,Ky,'Ky')
ax.text(Kx,-0.2,'Kx')

ax.legend(loc='lower left',fontsize = 8)

# %% [markdown]
# ## 4) **Etude d'une population répartie en deux structures, une culture et un augmentorium:**

# %% [markdown]
# ### Equilibres

# %% [markdown]
# On va considérer le système suivant :
# $$
# \left\{\begin{array}{1}
# \dot x = r_xx\left(1-\frac{x}{K_x}\right)-mx+fy\\
# \dot y = r_yy\left(1-\frac{y}{K_y}\right)+mx-fy
# \end{array}\right.
# $$
# avec $ \dot x $ la population de ravageurs dans la culture et $ \dot y $ celle dans l'augmentorium.
# $ m $ est alors le taux de fruit mis dans l'augmentorium et $ f $ le taux de fuite des ravageurs, de l'augmentorium vers la culture.

# %% [markdown]
# On remarque qu'il y a deux équilibres (intersection de nullclines). En $(0,0)$ et en $ (x_2,y_2)$. On va calculer $(x_2,y_2)$:

# %% [markdown]
# $$
# \left\{\begin{array}{1}
# \dot x = 0 \Leftrightarrow x_1=0 \vee y_2=\frac{x}{f}\left(r_x\left(\frac{x}{K_x}-1\right)+m\right)\\
# \dot y =0 \Leftrightarrow y_1=0 \vee x_2=\frac{y}{m}\left(r_y\left(\frac{y}{K_y}-1\right)+f\right)
# \end{array}\right.
# $$

# %%
#Définition du modèle et des paramètres :
def aug(etat,t,param):
    rx,ry,Kx,Ky,m,f=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-m*x+f*y,ry*y*(1-y/Ky)+m*x-f*y]
    return s 

# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres:
rx=0.5
ry=1
Kx=2
Ky=1
m=2
f=0.2

param_aug=np.array([rx,ry,Kx,Ky,m,f])

# Simulation:
s=odeint(aug,e0,ti,args=(param_aug,))

#Plan de phase:
fig2,ax2=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax2.plot(xt,xt*(1/f)*(rx*((xt/Kx)-1)+m),color='C2',label='xdot=0')
ax2.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax2.plot(yt*(1/m)*(ry*((yt/Ky)-1)+f),yt,color='C3',label='ydot=0')
ax2.plot(xt,np.zeros_like(xt),color='C2')

ax2.set_xlim(left=-1,right=3)
ax2.set_ylim(top=3,bottom=-1)
#ax2.plot(s[:,0],s[:,1],label='Trajectoire de la pop.')
ax2.set_xlabel('x',fontsize='12')
ax2.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax2.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C7')

# %% [markdown]
# On voit que $(0,0)$ est un équilibre, pour calculer $(x_2,y_2)$ on va injecter $x_2$ dans $y_2$ ce qui donne :

# %% [markdown]
# $$
# y\left[\frac{1}{mf}(r_x-m)(r_y-f)-1\right]+\frac{y^2}{mf}\left[\frac{r_y}{K_y}\left(m-r_x\right)+\frac{r_x}{mK_x}\left(r_y-f\right)^2\right]+\frac{2y^3r_xr_y}{m^2fK_xK_y}\left(f-r_y\right)+\frac{y^4r_xr_y}{m^2fK_xK_y^2} = 0
# $$

# %% [markdown]
# Qu'on va résoudre:

# %%
#Définition du modèle et des paramètres :
def aug(etat,t,param):
    rx,ry,Kx,Ky,m,f=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-m*x+f*y,ry*y*(1-y/Ky)+m*x-f*y]
    return s 
# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres:
rx=0.5
ry=1
Kx=2
Ky=1
m=2
f=0.2

param_aug=np.array([rx,ry,Kx,Ky,m,f])

# Simulation:
s=odeint(aug,e0,ti,args=(param_aug,))

###
#Monome y
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol = y*((1/(m*f))*(rx-m)*(ry-f)-1) + (y**2)*(1/(m*f))*(ry/Ky*(m-rx)+rx/(m*Kx)*(ry-f)**2)+2*(y**3*rx*ry)/(m**2*f*Kx*Ky)*(f-ry) + y**4*rx*ry/(m**2*f*Kx*Ky**2)
#pol2 = y*(1-ry/b-rx/b+(rx*ry)/(b**2)) + (y**2)*(ry/(b*Ky)+rx/(b*Kx)-(rx*ry)/((b**2)*Ky)-(2*rx*ry)/((b**2)*Kx)+(rx*(ry**2))/((b**3)*Kx))+(y**3)*((2*rx*ry)/((b**2)*Kx*Ky)-(2*rx*(ry**2))/((b**3)*Kx*Ky))+(y**4)*(rx*(ry**2))/((b**3)*Kx*(Ky**2))
#Solution
sol = pol.roots()[(np.isreal(pol.roots())) 
            *(pol.roots() > 0)]
yeq=sol[0].real
xeq=(yeq/m*(ry*(yeq/Ky-1)+f)).real
###


#Plan de phase:
fig2,ax2=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax2.plot(xt,xt*(1/f)*(rx*((xt/Kx)-1)+m),color='C2',label='xdot=0')
ax2.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax2.plot(yt*(1/m)*(ry*((yt/Ky)-1)+f),yt,color='C3',label='ydot=0')
ax2.plot(xt,np.zeros_like(xt),color='C2')

ax2.set_xlim(left=-1,right=3)
ax2.set_ylim(top=3,bottom=-1)
#ax2.plot(s[:,0],s[:,1],label='Trajectoire de la pop.')
ax2.set_xlabel('x',fontsize='12')
ax2.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax2.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C7')


ax2.plot(xeq.real,yeq.real,label='Equilibre stable',marker='.',markersize=10)
ax2.plot(0,0,label='Equilibre Instable',marker='.',markersize=10)

ax2.legend(loc='upper right')

# Ajout du champ de vecteur
xg=np.arange(0,5,0.6)
yg=np.arange(0,5,0.6)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug)
ax2.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=80,width=0.003)

# %% [markdown]
# De plus, en faisant $ x^* + y^* $ on a (en abandonnant les étoiles par commodité):
# $$
# r_xx\left(1-\frac{x}{K_x}\right)+r_yy\left(1-\frac{y}{K_y}\right) = 0 \\
# $$
# autrement dit l'équation d'une ellipse. Donc les points d'équilibres vivent sur une même ellipse (si on ne modifie que m et f), qu'on va tracer :

# %%
######
#Définition du modèle et des paramètres :
def aug(etat,t,param):
    rx,ry,Kx,Ky,m,f=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-m*x+f*y,ry*y*(1-y/Ky)+m*x-f*y]
    return s 
# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres:
rx=0.5
ry=1
Kx=2
Ky=1
m=2
f=0.2

param_aug=np.array([rx,ry,Kx,Ky,m,f])

# Simulation:
s=odeint(aug,e0,ti,args=(param_aug,))

###
#Monome y
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol = y*((1/(m*f))*(rx-m)*(ry-f)-1) + (y**2)*(1/(m*f))*(ry/Ky*(m-rx)+rx/(m*Kx)*(ry-f)**2)+2*(y**3*rx*ry)/(m**2*f*Kx*Ky)*(f-ry) + y**4*rx*ry/(m**2*f*Kx*Ky**2)
#pol2 = y*(1-ry/b-rx/b+(rx*ry)/(b**2)) + (y**2)*(ry/(b*Ky)+rx/(b*Kx)-(rx*ry)/((b**2)*Ky)-(2*rx*ry)/((b**2)*Kx)+(rx*(ry**2))/((b**3)*Kx))+(y**3)*((2*rx*ry)/((b**2)*Kx*Ky)-(2*rx*(ry**2))/((b**3)*Kx*Ky))+(y**4)*(rx*(ry**2))/((b**3)*Kx*(Ky**2))
#Solution
sol = pol.roots()[(np.isreal(pol.roots())) 
            *(pol.roots() > 0)]
yeq=sol[0].real
xeq=(yeq/m*(ry*(yeq/Ky-1)+f)).real
###


#Plan de phase:
fig2,ax2=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax2.plot(xt,xt*(1/f)*(rx*((xt/Kx)-1)+m),color='C2',label='xdot=0')
ax2.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax2.plot(yt*(1/m)*(ry*((yt/Ky)-1)+f),yt,color='C3',label='ydot=0')
ax2.plot(xt,np.zeros_like(xt),color='C2')

ax2.set_xlim(left=-1,right=3)
ax2.set_ylim(top=3,bottom=-1)
#ax2.plot(s[:,0],s[:,1],label='Trajectoire de la pop.')
ax2.set_xlabel('x',fontsize='12')
ax2.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax2.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C7')


ax2.plot(xeq.real,yeq.real,label='Equilibre stable',marker='.',markersize=10)
ax2.plot(0,0,label='Equilibre Instable',marker='.',markersize=10)

ax2.legend(loc='upper right')

# Ajout du champ de vecteur
xg=np.arange(0,5,0.6)
yg=np.arange(0,5,0.6)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug)
ax2.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=50,width=0.003)
######
#Trace de l'ellipse:
xg2=np.arange(-5,5,0.01)
yg2=np.arange(-5,5,0.01)
X2,Y2=np.meshgrid(xg2,yg2)
X=rx*X2*(1-X2/Kx)
Y=ry*Y2*(1-Y2/Ky)
ax2.contour(X2,Y2,(X+Y),[0],colors='C1')
ax2.plot(0,0,color='C1',label='Ellipse des solutions')
ax2.legend(loc='lower left',fontsize = 8)

# %% [markdown]
# Si l'équilbre est au dessus de la droite cian alors on dit que le système subit une inflation c'est à dire que la valeur de l'équilibre final vaut plus que les deux capacités biotiques réunies ($ 1+1 \ne 2$). Petite animation Geogebra pour bien voir en fonction de m et f que l'équilibre vit sur l'ellipse.

# %%
import IPython.display as display
fig01 = """
<iframe width="800" height="600" src="https://www.geogebra.org/classic/bhhpgtqv" style="border: 1px solid black"></iframe>
"""
display.HTML(fig01)
# Out:
# <iframe width="800" height="600" src="https://www.geogebra.org/classic/bhhpgtqv" style="border: 1px solid black"></iframe>

# %% [markdown]
# **Stabilité des équilibres:**
# Il est clair que $(0,0)$ est instable et $(x^*,y^*)$ est stable par le champ de vecteur et la façon dont se croisent les paraboles.

# %% [markdown]
# ### Tangente et condition suffisante à un système déflationiste:

# %% [markdown]
# On remarque que le point$ (K_x,K_y)$ est en permanence sur la droite $K_x+K_y$ qui coupe en permanence l'ellipse sauf pour une situation où la droite $K_x+K_y$ est tangente à l'ellipse. Ce cas nous interesse car il rend compte d'un système entièrement déflationiste.
# L'ellipse d'équation : $f(x,y)=r_xx\left(1-\frac{x}{K_x}\right)+r_yy\left(1-\frac{y}{K_y}\right) = 0 $ peut être vue comme la ligne de niveau de $f$ en $0$. Ainsi une équation de la tangente au point $(x_0,y_0)$ serait donnée par:
# $  \frac{\partial f}{\partial x}(x_0,y_0)(x-x_0)+ \frac{\partial f}{\partial y}(x_0,y_0)(y-y_0) = 0$
#
# Dans le cas où $x_0=Kx y_0=Ky$ on a alors $y=-\frac{r_x}{r_y}\left(x-K_x\right) + K_y$ équation de la tangente au point $(K_x,K_y)$.
#
# Pour que le système soit déflationiste on veut que cette équation ait une pente de $-1$ afin d'avoir l'équation de la droite $K_x+K_y$ et garantir la déflation. Ainsi on veut que $r_x=r_y$.
#
# On sait donc que si le taux de croissance est égale entre les deux structures le système est tout le temps déflationiste.

# %%
######
#Définition du modèle et des paramètres :
def aug(etat,t,param):
    rx,ry,Kx,Ky,m,f=param
    x,y=etat
    s=[rx*x*(1-x/Kx)-m*x+f*y,ry*y*(1-y/Ky)+m*x-f*y]
    return s 
# Temps d'intégration
ti = np.arange(0,10,0.01)

# Etats initiaux
x0=2
y0=0
e0=[x0,y0]

# Paramètres:
rx=0.5
ry=1
Kx=2
Ky=1
m=2
f=0.2

param_aug=np.array([rx,ry,Kx,Ky,m,f])

# Simulation:
s=odeint(aug,e0,ti,args=(param_aug,))

###
#Monome y
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol = y*((1/(m*f))*(rx-m)*(ry-f)-1) + (y**2)*(1/(m*f))*(ry/Ky*(m-rx)+rx/(m*Kx)*(ry-f)**2)+2*(y**3*rx*ry)/(m**2*f*Kx*Ky)*(f-ry) + y**4*rx*ry/(m**2*f*Kx*Ky**2)
#pol2 = y*(1-ry/b-rx/b+(rx*ry)/(b**2)) + (y**2)*(ry/(b*Ky)+rx/(b*Kx)-(rx*ry)/((b**2)*Ky)-(2*rx*ry)/((b**2)*Kx)+(rx*(ry**2))/((b**3)*Kx))+(y**3)*((2*rx*ry)/((b**2)*Kx*Ky)-(2*rx*(ry**2))/((b**3)*Kx*Ky))+(y**4)*(rx*(ry**2))/((b**3)*Kx*(Ky**2))
#Solution
sol = pol.roots()[(np.isreal(pol.roots())) 
            *(pol.roots() > 0)]
yeq=sol[0].real
xeq=(yeq/m*(ry*(yeq/Ky-1)+f)).real
###


#Plan de phase:
fig2,ax2=plt.subplots(1,1)
fig.suptitle('Plan de phase de la population')

# Isocline nulles
#xdot = 0
yt=np.arange(-10,10,0.01)
xt=np.arange(-10,10,0.01)
ax2.plot(xt,xt*(1/f)*(rx*((xt/Kx)-1)+m),color='C2',label='xdot=0')
ax2.plot(np.zeros_like(yt),yt,color='C3')
#ydot = 0
ax2.plot(yt*(1/m)*(ry*((yt/Ky)-1)+f),yt,color='C3',label='ydot=0')
ax2.plot(xt,np.zeros_like(xt),color='C2')

ax2.set_xlim(left=-1,right=3)
ax2.set_ylim(top=3,bottom=-1)
#ax2.plot(s[:,0],s[:,1],label='Trajectoire de la pop.')
ax2.set_xlabel('x',fontsize='12')
ax2.set_ylabel('y',fontsize='12')

x=np.arange(0,10,0.01)
ax2.plot(x,-x+Kx+Ky,label='Kx1+Ky1',color='C7')


ax2.plot(xeq.real,yeq.real,label='Equilibre stable',marker='.',markersize=10)
ax2.plot(0,0,label='Equilibre Instable',marker='.',markersize=10)

ax2.legend(loc='upper right')

# Ajout du champ de vecteur
xg=np.arange(0,5,0.6)
yg=np.arange(0,5,0.6)
X,Y=np.meshgrid(xg,yg)

dx,dy=aug([X,Y],0,param_aug)
ax2.quiver(X,Y,dx,dy,angles='xy',color='grey',scale=50,width=0.003)
######
#Trace de l'ellipse:
xg2=np.arange(-5,5,0.01)
yg2=np.arange(-5,5,0.01)
X2,Y2=np.meshgrid(xg2,yg2)
X=rx*X2*(1-X2/Kx)
Y=ry*Y2*(1-Y2/Ky)
ax2.contour(X2,Y2,(X+Y),[0],colors='C1')
ax2.plot(0,0,color='C1',label='Ellipse des solutions')
## Ajout des Kx,Ky et de la tangente
xv=np.arange(0,10)
ax2.plot(xv,-rx/ry*(xv-Kx)+Ky,color='C4',label='Tangente à (Kx,Ky)')
ax2.plot(0,Ky,marker='.',markersize=7,color='k')
ax2.plot(Kx,0,marker='.',markersize=7,color='k')
ax2.plot(Kx,Ky,marker='.',markersize=6,color='k')
xc=np.arange(0,Kx,0.01)
ax2.plot(xc,Ky*np.ones_like(xc),linestyle='dashed',color='k',linewidth=0.5)
yc=np.arange(0,Ky,0.01)
ax2.plot(Kx*np.ones_like(yc),yc,linestyle='dashed',color='k',linewidth=0.5)
ax2.text(-0.2,Ky,'Ky')
ax2.text(Kx,-0.2,'Kx')
ax2.legend(loc='lower left',fontsize = 8)

# %% [markdown]
# ## 5) Modèle complet de l'augmentorium :

# %% [markdown]
# ### Introduction :

# %% [markdown]
# L'augmentorium est un dispositif de lutte biologique mis en place dans les cultures touchées par la mouche des fruits.  Il peut être vu comme une tente où les fruits infectés sont entreposés. Le ravageur va alors continuer son cycle de reproduction dans l'augmentorium et les auxiliaires (parasites) vont pouvoir aussi s'y reproduire.
# Une grille permet, via une taille de maille optimale, d'empêcher le ravageur de ressortir de l'augmentorium mais de laisser librement les auxiliaires (plus petits) sortir.
#  Cette méthode permet d'augmenter le taux d'auxiliaire par rapport au ravageur.

# %% [markdown]
# ### Définition du modèle :

# %% [markdown]
# Pour simuler on va partir du modèle suivant :
# $$ \left\{\begin{array}{1}
# \dot x = r_xx\left(1-\frac{x}{K_x}\right)+\beta\left(\frac{y}{\gamma_y}-\frac{x}{\gamma_x}\right)-pxz \\
# \dot y = r_yy\left(1-\frac{y}{K_y}\right)+\beta\left(\frac{x}{\gamma_x}-\frac{y}{\gamma_y}\right)-pyz \\
# \dot z = z\left(n(x+y) - m\right)
# \end{array}\right.
# $$
#
# avec:
# - $r_x$ le taux de croissance de x dans la culture,
# - $r_y$ le taux de croissance de y dans l'augmentorium,
# - $K_x$ la capacité maximale de la culture,
# - $K_y$ la capacité maximale de l'augmentorium,
# - $\beta$ la force de migration,
# - $\gamma_x$ le taux d'assymétrie de la migration culture vers augmentorium,
# - $\gamma_y$ le taux d'assymétrie de la migration augmentorium vers culture,
# - $p$ la prédation de $z$ sur $x$ ou $y$
# - $n$ le taux de conversion proie prédateur (naissance due à la prédation),
# - $m$ la mortalité des prédateurs $z$.

# %% [markdown]
# ### Justification du modèle et quelques hypothèses

# %% [markdown]
# On s'appuie sur un modèle inspiré par Freedman et Waltman dans leur article de 1977. C'est plus généralement un modèle à deux structures, la culture (x) et l'augmentorium (y) où les proies grandissent selon une croissance logistique et les prédateurs une réponse fonctionelle de type 1. On suppose que les prédateurs diffusent librement entre la culture et l'augmentorium (très proche de la réalité voir article augmentorium) d'où la considération d'une seule population.
# La migration est assymétrique entre la culture et l'augmentorium, plus forte de la culutre vers l'augmentorium. On aura donc $\gamma_x < \gamma_y$.La capacité maximale de la culture est supposée plus forte que celle de l'augmentorium donc $K_x > K_y$. On supposera de plus que le taux de croissance dans la culture est plus faible que dans l'augmentorium, donc $r_x<r_y$.

# %% [markdown]
# ### Equilibres

# %% [markdown]
# On résout le système suivant :
#
# $$
# \left\{\begin{array}{1}
# 0 = r_xx\left(1-\frac{x}{K_x}\right)+\beta\left(\frac{y}{\gamma_y}-\frac{x}{\gamma_x}\right)-pxz \\
# 0 = r_yy\left(1-\frac{y}{K_y}\right)+\beta\left(\frac{x}{\gamma_x}-\frac{y}{\gamma_y}\right)-pyz \\
# 0 = z\left(n(x+y) - m\right)
# \end{array}\right.
# $$
#
# Si $z^*$=0:
# On reprend l'analyse de [Arditi et al](https://doi.org/10.1016/j.tpb.2017.12.006) de 2018.
# Ceci donne l'équilibre trivial $(0,0,0)$ (extinction des deux populations) et $(x_1^*,y_1^*,0)$ (disparition des parasites) où $x_1^*$ et $y_1^*$ sont les solutions du [système (3)](https://doi.org/10.1016/j.tpb.2017.12.006) proposé par Arditi en 2018 .
# Si $z^*\neq 0$:
# Il existe aussi un équilibre $(x_2^*,y_2^*,z_2^*)$ (co-existence parasite-ravageur).

# %% [markdown]
# #### Calcul de $(x_2^*,y_2^*,z_2^*)$ :

# %% [markdown]
# (1) donne :
# $$
# \left\{\begin{array}{1}
# 0 = r_xx\left(1-\frac{x}{K_x}\right)+\beta\left(\frac{y}{\gamma_y}-\frac{x}{\gamma_x}\right)-pxz \\
# 0 = r_yy\left(1-\frac{y}{K_y}\right)+\beta\left(\frac{x}{\gamma_x}-\frac{y}{\gamma_y}\right)-pyz \\
# x+y = \frac{m}{n}
# \end{array}\right.  $$
# et on exprime les deux premières équations en fonction de x ou z :
# $$
# \left\{\begin{array}{1}
# z_1 =  \frac{r_x}{p} -\frac{\beta}{p}\left(\frac{1}{\gamma_x}+\frac{1}{\gamma_y}\right) -\frac{r_xx}{pK_x}+\frac{\beta m}{np\gamma_yx}    \\
# z_2 =  \frac{r_y}{p} -\frac{\beta}{p}\left(\frac{1}{\gamma_y}+\frac{1}{\gamma_x}\right) -\frac{r_y(\frac{m}{n}-x)}{pK_y}+\frac{\beta m}{np\gamma_x(\frac{m}{n}-x)} \\
# x+y = \frac{m}{n}
# \end{array}\right.
# $$
#
# $x_2^*$ et $z_2^*$ correspondent à l'intersection des deux droites $z_1$ et $z_2$. $y_2^*$ est atteint en utilisant la troisième équation du système (2).

# %% [markdown]
# Pour $x^*_2$ :
# On le trouve en résolvant le polynôme suivant :
# $$(r_x - r_y) \left(\frac{m}{n}-x \right)x - x^2 \left(\frac{m}{n}-x \right)\frac{r_x}{K_x} + x \left(\frac{m}{n}-x \right)^2 \frac{r_y}{K_y} + \frac{\beta m}{n} \left( \frac{ \left(\frac{m}{n}-x \right) }{\gamma_y} - \frac{x}{\gamma_x} \right) = 0 $$
#
# Pour $y^*_2$ :
# On le retrouve en résolvant le polynôme suivant :
# $$(r_x - r_y) \left(\frac{m}{n}-y \right)y - y^2 \left(\frac{m}{n}-y \right)\frac{r_y}{K_y} + y \left(\frac{m}{n}-y \right)^2 \frac{r_x}{K_x} + \frac{\beta m}{n} \left( \frac{y}{\gamma_y} - \frac{\left(\frac{m}{n}-y \right)}{\gamma_x} \right) = 0 $$
#
# Pour $z^*_2$ :
# $$z^*_2=r_x

# %%
#Calcul de x*2
x=np.polynomial.Polynomial([0,1])
#Polynome :
#pol=(rx1/p1-ry1/p1)*x*(m1/n1-x) - (rx1*(x**2)/(p1*Kx1))*(m1/n1-x)+b1*m1/(n1*p1*gy1)*(m1/n1-x)+(ry1*(m1/n1-x)/(p1*Ky1))*x*(m1/n1-x) - (b1*m1/(n1*p1*gx1))*x
pol3=x*(m1/n1-x)*(rx1-ry1)-(x**2)*(m1/n1-x)*(rx1/Kx1)+x*((m1/n1-x)**2)*(ry1/Ky1)+(b1*(m1/n1))*(((m1/n1-x)/gy1)-(x/gx1))
sol=pol3.roots()[(np.isreal(pol3.roots())) *(pol3.roots() > 0)]

# %%
#Calcul de y*2
y=np.polynomial.Polynomial([0,1])
#Polynome :
pol=(rx1/p1-ry1/p1)*y*(m1/n1-y) - (rx1*((m1/n1-y)**2)/(p1*Kx1))*y+b1*m1/(n1*p1*gy1)*y+(ry1*y/(p1*Ky1))*(m1/n1-y)*y - (b1*m1/(n1*p1*gx1))*(m1/n1-y)

sol2=pol.roots()[(np.isreal(pol.roots())) *(pol.roots() > 0)]

# %% [markdown]
# #### Stabilité des équilibres

# %% [markdown]
# On va calculer la Jacobienne associée au système :
# $$
# \mathbb{J_{x,y,z}}  =  \left[\begin{array}{ccc}
# \ r_x-\frac{2r_xx}{K_x}-\frac{\beta}{\gamma_x}-pz & \frac{\beta}{\gamma_y} & -px \\
# \ \frac{\beta}{\gamma_x} & r_y -\frac{2r_yy}{K_y}-\frac{\beta}{\gamma_y}-pz & -py \\
# \ zn & zn & n(x+y)-m
# \end{array}\right]
# $$
#
# - $(0,0,0)$ :
# $$
# \mathbb{J_{0,0,0}}  =  \left[\begin{array}{ccc}
# \ r_x-\frac{\beta}{\gamma_x}& \frac{\beta}{\gamma_y} & 0 \\
# \ \frac{\beta}{\gamma_x} & r_y-\frac{\beta}{\gamma_y}& 0 \\
# \ 0 & 0 &-m
# \end{array}\right]
# $$
#
# En calculant la trace et le déterminant on déduit que :
#
# Si $r_xr_y > \beta\left(\frac{r_x}{\gamma_y}+\frac{r_y}{\gamma_x}\right),  (0,0,0) $ est un point col.
# Si $r_xr_y < \beta\left(\frac{r_x}{\gamma_y}+\frac{r_y}{\gamma_x}\right) $ et $r_x+r_y>\beta\left(\frac{1}{\gamma_y}+\frac{1}{\gamma_x}\right)+m ,  (0,0,0) $ est un point d'équilibre instable.
# Si $r_xr_y < \beta\left(\frac{r_x}{\gamma_y}+\frac{r_y}{\gamma_x}\right) $ et $r_x+r_y<\beta\left(\frac{1}{\gamma_y}+\frac{1}{\gamma_x}\right)+m ,  (0,0,0) $ est un point d'équilibre stable. Ce n'est jamais le cas car la première condition impose la condition d'équilibre instable.
#
# - $(x_1^*,y_1^*,0)$ :
# $$
# \mathbb{J_{x_1^*,y_1^*,0}}  =  \left[\begin{array}{ccc}
# \ r_x-\frac{2r_xx_1^*}{K_x}-\frac{\beta}{\gamma_x}& \frac{\beta}{\gamma_y} & -px_1^* \\
# \ \frac{\beta}{\gamma_x} & r_y -\frac{2r_yy_1^*}{K_y}-\frac{\beta}{\gamma_y}& -py_1^* \\
# \ 0 & 0 & n(x_1^*+y_1^*)-m
# \end{array}\right]
# $$
#
# Cet équilibre est stable, on peut le voir graphiquement en tracant les nullclines associées à ce système.
#
# - $(x_2^*,y_2^*,z_2^*)$ :
# Stable !

# %% [markdown]
# ### Simulation Python :

# %%
#Définition du modèle:

def a(etat,t,param):
    x,y,z=etat
    rx,Kx,ry,Ky,gx,gy,b,p,n,m = param
    xdot,ydot,zdot=[rx*x*(1-x/Kx)+b*(y/gy-x/gx)-p*z*x,ry*y*(1-y/Ky)+b*(x/gx-y/gy)-p*y*z,z*(n*(x+y)-m)]
    return [xdot,ydot,zdot]

#Paramètres Simulation 1: 

rx1=0.5
ry1=1
Kx1=2
Ky1=1
gx1=0.5
gy1=3
b1=1
p1=1
n1=1
m1=0.5


param_a1=np.array([rx1,Kx1,ry1,Ky1,gx1,gy1,b1,p1,n1,m1])

#Paramètres Simulation 2: 

rx2=0.5
ry2=1
Kx2=2
Ky2=1
gx2=0.5
gy2=3
b2=1
p2=1
n2=1
m2=2


param_a2=np.array([rx2,Kx2,ry2,Ky2,gx2,gy2,b2,p2,n2,m2])

#Paramètres Simulation 3: 

rx=0.5
ry=1
Kx=2
Ky=1
gx=0.5
gy=3
b=1
p=1
n=1
m=0.5


#param_a3=np.array([rx3,Kx3,ry3,Ky3,gx3,gy3,b3,p3,n3,m3])


#Temps d'intégration

t1=np.arange(0,200,0.01)
t2=np.arange(0,50,0.01)
t3=np.arange(0,100,0.01)

#Condition initiale:

x0=3
y0=1
z0=0.5
c0=np.array([x0,y0,z0])

#Simulation 1,2,

s1=odeint(a,c0,t1,args=(param_a1,))
s2=odeint(a,c0,t2,args=(param_a2,))
#s3=odeint(a,c0,t3,args=(param_a3,))


#Plot de la figure : 

fig,ax = plt.subplots(2,1,figsize=(5,8))
fig.suptitle('Simulation du modèle d\'augmentorium')
plt.subplots_adjust(hspace=0.4)

#Plot de l'axe 1
ax[0].plot(t1,s1[:,0],color='C0',label='Ravageur dans la culture')
ax[0].plot(t1,s1[:,1],color='C1',label='Ravageur dans l\'augmentorium')
ax[0].plot(t1,s1[:,2],color='C6',label='Prédateurs totaux')
ax[0].set_ylabel('Population, x,y,z')
ax[0].legend(fontsize=8)
ax[0].grid()
ax[0].set_ylim(top=3,bottom=-0.05)
ax[0].set_title('Coexistence des trois populations',fontsize=7.5)

#Plot de l'axe 2
ax[1].plot(t2,s2[:,0],color='C0',label='Ravageur dans la culture')
ax[1].plot(t2,s2[:,1],color='C1',label='Ravageur dans l\'augmentorium')
ax[1].plot(t2,s2[:,2],color='C6',label='Prédateurs totaux')
ax[1].set_xlabel('Temps, t')
ax[1].set_ylabel('Population, x,y,z')
ax[1].legend(fontsize=8)
ax[1].grid()
ax[1].set_ylim(top=3,bottom=-0.05)
ax[1].set_title('Disparition des parasites,maintien des ravageurs',fontsize=7.5)

#Plot de l'axe 3
#ax[2].plot(t3,s3[:,0],color='C0',label='Culture')
#ax[2].plot(t3,s3[:,1],color='C1',label='Augmentorium')
#ax[2].plot(t3,s3[:,2],color='C6',label='Parasites')
#ax[2].set_xlabel('Temps, t')
#ax[2].set_ylabel('Population, x,y,z')
#ax[2].legend()
#ax[2].set_ylim(top=5,bottom=-0.05)
#ax[2].grid()
#ax[2].set_title('Disparition des parasites,maintien des ravageurs',fontsize=7.5)


x=np.polynomial.Polynomial([0,1])
#Polynome :
pol=(rx1/p1-ry1/p1)*x*(m1/n1-x) - (rx1*(x**2)/(p1*Kx1))*(m1/n1-x)+b1*m1/(n1*p1*gy1)*(m1/n1-x)+(ry1*(m1/n1-x)/(p1*Ky1))*x*(m1/n1-x) - (b1*m1/(n1*p1*gx1))*x

sol=pol.roots()[(np.isreal(pol.roots())) *(pol.roots() > 0)]
sol
# Out:
# array([0.06921726, 1.22015223])

# %% [markdown]
# On observe via ces simulations les deux équilibres stables possibles. L'équilibre (0,0,0) est instable donc on ne peut pas l'atteindre via simulations.

# %% [markdown]
# ### Plan de phase

# %%
import IPython.display as display
fig01 = """
<iframe width="800" height="600" src="https://www.geogebra.org/3d/ngsqrv9v" style="border: 1px solid black"></iframe>
"""
display.HTML(fig01)
# Out:
# <iframe width="800" height="600" src="https://www.geogebra.org/3d/ngsqrv9v" style="border: 1px solid black"></iframe>
